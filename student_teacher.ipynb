# %% [markdown]
# <a href="https://colab.research.google.com/github/aaramm/Clustering/blob/master/student_teacher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!wget ftp://guest:GU%2E205dldo@ftp.softronics.ch/mvtec_anomaly_detection/carpet.tar.xz
# Out:
# --2021-07-31 08:25:58--  ftp://guest:*password*@ftp.softronics.ch/mvtec_anomaly_detection/carpet.tar.xz
#            => ‘carpet.tar.xz’
# Resolving ftp.softronics.ch (ftp.softronics.ch)... 168.119.117.96
# Connecting to ftp.softronics.ch (ftp.softronics.ch)|168.119.117.96|:21... connected.
# Logging in as guest ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /mvtec_anomaly_detection ... done.
# ==> SIZE carpet.tar.xz ... 740285760
# ==> PASV ... done.    ==> RETR carpet.tar.xz ... done.
# Length: 740285760 (706M) (unauthoritative)
#
# carpet.tar.xz       100%[===================>] 705.99M  6.25MB/s    in 1m 53s
#
# 2021-07-31 08:27:54 (6.25 MB/s) - ‘carpet.tar.xz’ saved [740285760]

# %%
#!tar xvf /content/carpet.tar.xz
# Out:
# carpet/
# carpet/ground_truth/
# carpet/ground_truth/color/
# carpet/ground_truth/color/016_mask.png
# carpet/ground_truth/color/017_mask.png
# carpet/ground_truth/color/018_mask.png
# carpet/ground_truth/color/000_mask.png
# carpet/ground_truth/color/001_mask.png
# carpet/ground_truth/color/002_mask.png
# carpet/ground_truth/color/003_mask.png
# carpet/ground_truth/color/004_mask.png
# carpet/ground_truth/color/005_mask.png
# carpet/ground_truth/color/006_mask.png
# carpet/ground_truth/color/007_mask.png
# carpet/ground_truth/color/008_mask.png
# carpet/ground_truth/color/009_mask.png
# carpet/ground_truth/color/010_mask.png
# carpet/ground_truth/color/011_mask.png
# carpet/ground_truth/color/012_mask.png
# carpet/ground_truth/color/013_mask.png
# carpet/ground_truth/color/014_mask.png
# carpet/ground_truth/color/015_mask.png
# carpet/ground_truth/cut/
# carpet/ground_truth/cut/000_mask.png
# carpet/ground_truth/cut/001_mask.png
# carpet/ground_truth/cut/002_mask.png
# ...

# %%
#!mkdir data

# %%
# %cd /content/drive/MyDrive/student-teacher-anomaly-detection
# Out:
# /content/drive/MyDrive/student-teacher-anomaly-detection

# %%
# !mv /content/carpet /content/data

# %%
# !git clone https://github.com/denguir/student-teacher-anomaly-detection.git
# Out:
# Cloning into 'student-teacher-anomaly-detection'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 215 (delta 11), reused 21 (delta 7), pack-reused 185
# Receiving objects: 100% (215/215), 286.11 MiB | 35.03 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# Checking out files: 100% (40/40), done.

# %%
# %cd /content/student-teacher-anomaly-detection
# Out:
# /content/student-teacher-anomaly-detection

# %%
# !mv /content/data /content/student-teacher-anomaly-detection

# %%
# !chmod -R u+rw data

# %%
# !./mvtec_dataset.sh carpet
# Out:
# Moved test images into data/carpet/img
# Moved train images into data/carpet/img
# CSV file built
# model/carpet already exists

# %%
# %cd /content/student-teacher-anomaly-detection/src
# Out:
# /content/student-teacher-anomaly-detection/src

# %%
# !pip3 install einops

# %%
# !python3 /content/student-teacher-anomaly-detection/src/resnet18_training.py carpet
# Out:
# Device used: cuda:0
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 189MB/s]
# Loading of resnet18.pt succesful.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !mv /content/student-teacher-anomaly-detection /content/drive/MyDrive
